# %%
import numpy as np

# %%
a = np.array([1,2,3,4,5])
print(a)
# Out:
# [1 2 3 4 5]

# %%
b = a.T
print(b)
# Out:
# [1 2 3 4 5]

# %%
c = np.array([[1,2],[3,4]])
print(c)
# Out:
# [[1 2]
#  [3 4]]

# %%
d = c.T
print(d)
# Out:
# [[1 3]
#  [2 4]]

# %% [markdown]
# ## BROADCASTING

# %%
e = np.array([1,2,3])
print(e)
g = e+5
print(g)
# Out:
# [1 2 3]
# [6 7 8]

# %%
h = np.array([1,2,3])
print(h)
i = h+[1]
print(i)
# Out:
# [1 2 3]
# [2 3 4]

# %%
j = np.array([[1,2,3],[4,5,6]])
print(j)
z1 = np.array([100])
z2 = j+z1
z2
# Out:
# [[1 2 3]
#  [4 5 6]]
# array([[101, 102, 103],
#        [104, 105, 106]])

# %%
j = np.array([[1,2,3],[4,5,6]])
print(j)
z1 = np.array([100,200])
z2 = j+z1
z2
# Out:
# [[1 2 3]
#  [4 5 6]]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 4
#       2 print(j)
#       3 z1 = np.array([100,200])
# ----> 4 z2 = j+z1
#       5 z2
#
# ValueError: operands could not be broadcast together with shapes (2,3) (2,)

# %%
j = np.array([[1,2,3],[4,5,6]])
print(j)
z1 = np.array([100,200,300])
z2 = j+z1
z2
# Out:
# [[1 2 3]
#  [4 5 6]]
# array([[101, 202, 303],
#        [104, 205, 306]])

# %%
k = j.itemsize
print(k)
l = np.array([1, 2, 3, 4], dtype = float) 
print(l)
print(l.itemsize)
# Out:
# 8
# [1. 2. 3. 4.]
# 8

# %% [markdown]
# ## MATRIX MULTIPLICATION

# %%
m = np.array([1,2,3])
n = np.array([4,5,6])
print(m@n)
# Out:
# 32

# %% [markdown]
# ## STATISTICS

# %%
o = np.array([[5,13,3],[2,3,4]])

# %%
o = np.array([[5,13,3],[2,3,4]])
print(o)
print(o.min())
# Out:
# [[ 5 13  3]
#  [ 2  3  4]]
# 2

# %%
o.min()
# Out:
# np.int64(2)

# %%
o.max()
# Out:
# np.int64(13)

# %%
o.mean()
# Out:
# np.float64(5.0)

# %%
o.std()
# Out:
# np.float64(3.696845502136472)

# %%
import numpy as np
a = np.array([1,2,3])
print(a)
# Out:
# [1 2 3]

# %%
p = np.array([[35,12,48,60],[50,55,53,56],[28,30,27,29],[45,48,50,47],[60,65,63,66],[33,37,35,34],[49,51,50,48],[29,31,30,32]])
print(p)
print(p.ndim)
# Out:
# [[35 12 48 60]
#  [50 55 53 56]
#  [28 30 27 29]
#  [45 48 50 47]
#  [60 65 63 66]
#  [33 37 35 34]
#  [49 51 50 48]
#  [29 31 30 32]]
# 2

# %%
r = np.mean(p, axis=1)
print(r)
# Out:
# [38.75 53.5  28.5  47.5  63.5  34.75 49.5  30.5 ]

# %%
for i in range(8):
    check = True
    for j in range(4):
        if(p[i][j]>55):
            check = False
    if(check == True):
        print(p[i])
# Out:
# [28 30 27 29]
# [45 48 50 47]
# [33 37 35 34]
# [49 51 50 48]
# [29 31 30 32]

# %%
for i in range(8):
    sum = 0
    per = 0
    for j in range(3):
        sum += p[i][j]
        per = (j/3);
    print(sum)
    print(per)
    if p[i][3]>per:
        print(p[i])
# Out:
# 95
# 0.6666666666666666
# [35 12 48 60]
# 158
# 0.6666666666666666
# [50 55 53 56]
# 85
# 0.6666666666666666
# [28 30 27 29]
# 143
# 0.6666666666666666
# [45 48 50 47]
# 188
# 0.6666666666666666
# [60 65 63 66]
# 105
# 0.6666666666666666
# [33 37 35 34]
# 150
# 0.6666666666666666
# [49 51 50 48]
# 90
# 0.6666666666666666
# [29 31 30 32]
